# %% [markdown]
# # Using bia-bob using KISSKI Infrastructure
# To execute this notebook, you need to apply for a KISSKI API key [here](https://kisski.gwdg.de/en/leistungen/2-02-llm-service/).

# %%
from bia_bob import bob
bob.initialize(endpoint="https://chat-ai.academiccloud.de/v1", 
               api_key="<enter your KISSKI API key here>", # never share your API key with others!
               model="meta-llama-3.1-70b-instruct")
# Out:
#             <div style="font-size:7pt">
#             This notebook may contain text, code and images generated by artificial intelligence.
#             Used model: meta-llama-3.1-70b-instruct, vision model: None, endpoint: https://chat-ai.academiccloud.de/v1, bia-bob version: 0.23.0.. Do not enter sensitive or private information and verify generated contents according to good scientific practice. Read more: <a href="https://github.com/haesleinhuepf/bia-bob#disclaimer">https://github.com/haesleinhuepf/bia-bob#disclaimer</a>
#             </div>

# %%
# %%bob
# load blobs.tif and visualize it

# %%
import numpy as np
import pyclesperanto_prototype as cle
import stackview
from skimage.io import imread, imshow
from skimage import data
import matplotlib.pyplot as plt

image = imread("blobs.tif")
stackview.insight(image)
# Out:
# StackViewNDArray([[ 40,  32,  24, ..., 216, 200, 200],
#                   [ 56,  40,  24, ..., 232, 216, 216],
#                   [ 64,  48,  24, ..., 240, 232, 232],
#                   ...,
#                   [ 72,  80,  80, ...,  48,  48,  48],
#                   [ 80,  80,  80, ...,  48,  48,  48],
#                   [ 96,  88,  80, ...,  48,  48,  48]], dtype=uint8)
